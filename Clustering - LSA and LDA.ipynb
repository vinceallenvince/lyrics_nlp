# %% [markdown]
# ### Clustering - LSA and LDA
# Algorithms to infer topic distribution across a set of documents.

# %%
from gensim import corpora, models, similarities
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
import json

# %%
corpus = CategorizedPlaintextCorpusReader("corpus/lyrics/tokenized/", r".*\.txt", cat_pattern=r"(\w+)/*", encoding="utf8")

# %%
tracks_all = []
for x in range(0, len(corpus.fileids())):
    tracks_all.append(corpus.raw(corpus.fileids()[x]))

# %%
texts = [text.split(' ') for text in tracks_all]

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=1, no_above=0.8)

# %%
corpus_doc2bow = [dictionary.doc2bow(text) for text in texts]

# %% [markdown]
# ### Latent semantic analysis
# Analyzes relationships between a set of documents and the terms they contain by producing a set of concepts related to the documents and terms. LSA assumes that words that are close in meaning will occur in similar pieces of text.
# https://en.wikipedia.org/wiki/Latent_semantic_analysis

# %%
# %time lsi = models.lsimodel.LsiModel(corpus=corpus_doc2bow, id2word=dictionary, num_topics=50)
# Out:
# CPU times: user 82.3 ms, sys: 7.33 ms, total: 89.7 ms
# Wall time: 102 ms

# %%
lsi.print_topics(5)
# Out:
# [(0,
#   u'0.348*"got" + 0.311*"get" + 0.267*"line" + 0.241*"rock" + 0.239*"well" + 0.230*"island" + 0.205*"time" + 0.155*"good" + 0.153*"road" + 0.152*"said"'),
#  (1,
#   u'0.349*"cry" + 0.269*"tell" + -0.267*"island" + -0.260*"rock" + -0.246*"line" + 0.209*"time" + -0.168*"ride" + -0.166*"road" + -0.155*"got" + 0.154*"town"'),
#  (2,
#   u'0.644*"high" + 0.399*"rising" + 0.396*"feet" + 0.309*"water" + 0.144*"two" + 0.123*"five" + 0.123*"mama" + 0.122*"papa" + -0.117*"get" + -0.098*"cry"'),
#  (3,
#   u'-0.600*"get" + -0.276*"blues" + 0.276*"cry" + -0.272*"rhythm" + 0.268*"tell" + 0.135*"guns" + -0.126*"time" + 0.121*"line" + 0.116*"island" + 0.110*"take"'),
#  (4,
#   u'0.571*"run" + 0.402*"softly" + 0.391*"river" + 0.383*"blue" + 0.169*"cool" + 0.169*"deep" + 0.167*"darlin" + 0.167*"asleep" + -0.150*"cry" + -0.091*"tell"')]

# %%
topics_matrix = lsi.show_topics(formatted=False, num_words=10)
topics_matrix
# Out:
# [(0,
#   [(u'got', 0.34752773991406433),
#    (u'get', 0.31097541704509069),
#    (u'line', 0.26711794424678126),
#    (u'rock', 0.24071101094141703),
#    (u'well', 0.23948183236937387),
#    (u'island', 0.22982140855641484),
#    (u'time', 0.20486679021930854),
#    (u'good', 0.15502785269628513),
#    (u'road', 0.15288514696012148),
#    (u'said', 0.15181569094664693)]),
#  (1,
#   [(u'cry', 0.34864357636293997),
#    (u'tell', 0.26878872861872843),
#    (u'island', -0.26707967681043315),
#    (u'rock', -0.26045609497267469),
#    (u'line', -0.2461362626302907),
#    (u'time', 0.20915395732049635),
#    (u'ride', -0.16835451154099848),
#    (u'road', -0.16642676334023965),
#    (u'got', -0.15459607045045556),
#    (u'town', 0.15354216559579018)]),
#  (2,
#   [(u'high', 0.64352240169291275),
#    (u'rising', 0.3988995255810856),
#    (u'feet', 0.39648956834024901),
#    (u'water', 0.30921542090188286),
#    (u'two', 0.14418482982574898),
#    (u'five', 0.12274965792544419),
#    (u'mama', 0.12256504482692511),
#    (u'papa', 0.12208309312931348),
#    (u'get', -0.11658752293611997),
#    (u'cry', -0.09840094666743586)]),
#  (3,
#   [(u'get', -0.59987629451132329),
#    (u'blues', -0.27642445199632532),
#    (u'cry', 0.2758722409820778),
#    (u'rhythm', -0.27151509830720799),
#    (u'tell', 0.26838871812932996),
#    (u'guns', 0.13468724993732659),
#    (u'time', -0.12556369066736994),
#    (u'line', 0.12136421251389184),
#    (u'island', 0.11571772043277583),
#    (u'take', 0.11044266168985467)]),
#  (4,
#   [(u'run', 0.5711888470889277),
#    (u'softly', 0.40201129766906224),
#    (u'river', 0.39111027800871173),
#    (u'blue', 0.38324422866721281),
#    (u'cool', 0.16852604564190732),
#    (u'deep', 0.16852604564190732),
#    (u'darlin', 0.16749853634064393),
#    (u'asleep', 0.16749853634064393),
#    (u'cry', -0.1504212638900341),
#    (u'tell', -0.090713479579366832)]),
#  (5,
#   [(u'cry', -0.53411778169910917),
#    (u'guns', 0.37920484873869931),
#    (u'town', 0.32089170787502364),
#    (u'take', 0.26442371462300202),
#    (u'home', 0.17606188256483654),
#    (u'leave', 0.14038092486184933),
#    (u'dream', 0.13472645648640288),
#    (u'gonna', -0.13290914702671208),
#    (u'son', 0.11874935447510786),
#    (u'bill', 0.11822142855949754)]),
#  (6,
#   [(u'played', -0.56171490230137067),
#    (u'luther', -0.4199029311686856),
#    (u'boogie', -0.4199029311686856),
#    (u'woogie', -0.31492719837651417),
#    (u'get', 0.13864808125995098),
#    (u'make', -0.11475087609790281),
#    (u"ol'", -0.10567480689861011),
#    (u'cry', 0.10285119898276036),
#    (u'rhythm', 0.083575464676884925),
#    (u'kind', -0.080181246157779745)]),
#  (7,
#   [(u'time', 0.40377364434709678),
#    (u'cry', -0.39917642493777744),
#    (u'get', -0.20275401704322993),
#    (u'love', 0.18429917388642578),
#    (u'played', -0.16799157588073949),
#    (u'guns', -0.16431982100813708),
#    (u'picking', 0.15183009427143981),
#    (u'blues', -0.15091453178380165),
#    (u'rhythm', -0.14619142909539828),
#    (u'heart', 0.14551133430203614)]),
#  (8,
#   [(u'tell', 0.74161496740022859),
#    (u'cry', -0.31356861372600209),
#    (u'time', -0.21427318640316001),
#    (u'guns', -0.18708813322590645),
#    (u'left', 0.13673896399321045),
#    (u'picking', -0.11992476110764932),
#    (u'get', 0.11198005418167994),
#    (u'come', -0.11180223107997253),
#    (u'town', -0.11063880904608177),
#    (u'take', -0.10414117316697698)]),
#  (9,
#   [(u'dream', 0.32848719447007041),
#    (u'guns', -0.28960909758303138),
#    (u'queen', 0.26386278491958737),
#    (u'teenage', 0.26291494529741344),
#    (u'boy', 0.25020048393871031),
#    (u'tell', -0.24865030028130566),
#    (u'next', 0.20756576767820809),
#    (u'store', 0.19718620897306016),
#    (u'candy', 0.19718620897306016),
#    (u'door', 0.19621376246028394)]),
#  (10,
#   [(u'time', 0.40215189568101417),
#    (u'tell', 0.30245119366107293),
#    (u'picking', 0.29558930481520146),
#    (u'miss', -0.21694657165113646),
#    (u'katy', -0.21085310579622932),
#    (u'know', -0.1876191242048007),
#    (u'love', -0.18532709461313854),
#    (u'still', -0.18302043792386638),
#    (u'come', 0.17012263094483307),
#    (u'guess', -0.14521454534649186)]),
#  (11,
#   [(u'country', 0.42138414424235859),
#    (u'got', 0.39216763810818395),
#    (u'boy', 0.36251623417095441),
#    (u'man', -0.17976595647652885),
#    (u'baby', 0.15009231996248307),
#    (u'katy', -0.13848969236565936),
#    (u'work', 0.13765946443177027),
#    (u'like', -0.12988807346163933),
#    (u'lot', 0.12333183375848784),
#    (u'everybody', 0.1198134766222218)]),
#  (12,
#   [(u'katy', -0.34868970598307875),
#    (u'baby', 0.31261961866040527),
#    (u'everybody', 0.24980660868873697),
#    (u'country', -0.2390617294463579),
#    (u'mine', 0.21835023929225389),
#    (u'boy', -0.20623417923279352),
#    (u'coming', 0.16722462787495784),
#    (u'home', 0.16073181245236651),
#    (u"ol'", -0.15873435254774163),
#    (u'love', 0.15631229343815958)]),
#  (13,
#   [(u'katy', -0.41133484871377302),
#    (u'know', 0.25415494977407571),
#    (u'man', 0.2385233160467638),
#    (u'still', -0.21097993565821294),
#    (u'miss', -0.20869197973466944),
#    (u"ol'", -0.1929137633892021),
#    (u'guess', 0.18707439067036535),
#    (u'love', -0.14368987607984107),
#    (u'baby', -0.13982917067248871),
#    (u'never', 0.13790212400985891)]),
#  (14,
#   [(u'man', 0.33331482004337648),
#    (u'old', 0.25431589237597901),
#    (u'never', 0.22192403127611371),
#    (u'know', -0.22085870812132286),
#    (u'guess', -0.21675230591148009),
#    (u'died', 0.17384295014677245),
#    (u'stopped', 0.17110145788382516),
#    (u'short', 0.17077727378136726),
#    (u'years', 0.16821782274946948),
#    (u'tok', 0.13961208226228788)]),
#  (15,
#   [(u'heart', -0.35215838248662995),
#    (u'baby', 0.2185814948688603),
#    (u'love', -0.20813274385807831),
#    (u'guess', 0.19307130369046555),
#    (u'everybody', 0.16092739523673141),
#    (u'man', 0.16008846866177229),
#    (u'line', -0.15888346523403968),
#    (u'home', 0.15530763337379447),
#    (u'going', 0.15054190912135268),
#    (u'someone', -0.14219226469404853)]),
#  (16,
#   [(u'drink', -0.87599490119080992),
#    (u'orchid', -0.16424904397327691),
#    (u'honey', -0.10949936264885124),
#    (u'man', 0.095530825736486455),
#    (u'come', -0.080732217686753288),
#    (u'eyes', -0.066546362398531317),
#    (u'soul', -0.062642983666041763),
#    (u'took', -0.06085410521275178),
#    (u'rose', -0.058389687627411965),
#    (u'petals', -0.056569684475918793)]),
#  (17,
#   [(u'someone', -0.19402683062819212),
#    (u'guess', 0.19337130390928389),
#    (u'like', 0.18829341577605838),
#    (u'thanks', -0.18744753435059794),
#    (u'come', -0.18667973665269891),
#    (u'lot', -0.18531680065131151),
#    (u'miss', -0.17977041807605951),
#    (u'see', -0.17707297317946744),
#    (u'way', 0.16062947191872318),
#    (u'man', 0.15777491035936819)]),
#  (18,
#   [(u'long', -0.28574743460151619),
#    (u'heard', -0.25634578606800063),
#    (u'whistle', -0.22320781920960675),
#    (u'lonesome', -0.21830357091650351),
#    (u'thanks', 0.2156610673844907),
#    (u'blow', -0.21241383518335732),
#    (u'lot', 0.2031133965230055),
#    (u'come', 0.15404179905754284),
#    (u'love', 0.14738100699779824),
#    (u'katy', -0.14313651484556658)]),
#  (19,
#   [(u'katy', -0.27301224643845795),
#    (u'miss', 0.27245394072250723),
#    (u'someone', 0.25726050148753432),
#    (u'goodbye', 0.2325113026223084),
#    (u'guess', 0.19192796421494507),
#    (u'way', 0.16691312417955173),
#    (u'happen', 0.16429916113197066),
#    (u'darling', 0.16164226461893674),
#    (u'little', 0.16085722922348353),
#    (u'picking', 0.15772140560821288)]),
#  (20,
#   [(u'long', -0.23469161817833925),
#    (u'whistle', -0.22630192965025184),
#    (u'lonesome', -0.22379003640753287),
#    (u'blow', -0.22120664911540089),
#    (u'heard', -0.21466429124426448),
#    (u'man', 0.20672634551418639),
#    (u'lord', 0.16627337464988654),
#    (u'home', -0.15811730026855358),
#    (u'going', 0.14463410344305663),
#    (u'frankie', 0.13783296167141948)]),
#  (21,
#   [(u'lord', 0.32498619445555954),
#    (u'willing', 0.22715222845185271),
#    (u'good', 0.21289260417090503),
#    (u'guess', 0.19561150930567439),
#    (u'time', -0.19318815629128774),
#    (u'rise', 0.16363010194288849),
#    (u'way', 0.13963110935473824),
#    (u'heart', 0.13937516119049778),
#    (u'know', -0.13597861261229482),
#    (u'happen', 0.13279380066062074)]),
#  (22,
#   [(u'thanks', 0.244445504943995),
#    (u'lot', 0.23207056996684156),
#    (u'good', 0.20772616641081507),
#    (u'saved', -0.16574507459737206),
#    (u'willing', 0.16525461129423574),
#    (u'someone', -0.16118810404931092),
#    (u'old', -0.16052275986815967),
#    (u'within', -0.13214511198511211),
#    (u'peace', -0.13214511198511211),
#    (u'happened', -0.13214511198511211)]),
#  (23,
#   [(u'troubadour', 0.33224389156619044),
#    (u'heart', 0.29474805200510912),
#    (u'home', 0.17971595731222051),
#    (u'lord', -0.16637019559042093),
#    (u'miss', -0.15657122176434979),
#    (u'frankie', 0.15068768099778521),
#    (u'goodbye', -0.14516764760517603),
#    (u'picking', 0.14313776546975798),
#    (u'katy', 0.14105671318725338),
#    (u'well', 0.13505417087699956)]),
#  (24,
#   [(u'home', -0.26518364046103304),
#    (u'well', -0.17962104189416475),
#    (u'heaven', -0.16751994970004785),
#    (u'let', -0.16453479004170354),
#    (u'thing', -0.1626778947448155),
#    (u'nearest', -0.15946623538159529),
#    (u'away', -0.14948505407686644),
#    (u'heart', 0.14611015118215581),
#    (u'never', 0.14136346498022587),
#    (u'mother', -0.13950598616178206)]),
#  (25,
#   [(u'keep', -0.36204673993629266),
#    (u'mine', -0.24982800791869955),
#    (u'walk', -0.23259919001157112),
#    (u'someone', -0.19335362076806975),
#    (u'home', 0.18108342869610955),
#    (u'love', 0.17877698701751404),
#    (u'goodbye', 0.17840718846852369),
#    (u'still', -0.15959776095379102),
#    (u'darling', 0.15453833557104818),
#    (u'line', -0.15344436562067174)]),
#  (26,
#   [(u'goodbye', 0.40705687735211604),
#    (u'darling', 0.30577610307995867),
#    (u'keep', 0.24821842375306954),
#    (u'someone', -0.23698731059674935),
#    (u'little', 0.23438872864109303),
#    (u'mine', 0.19190393644705839),
#    (u'picking', 0.1487881309138184),
#    (u'katy', 0.14215556091210269),
#    (u'time', -0.13071552499678871),
#    (u'troubadour', -0.12788156687259761)]),
#  (27,
#   [(u'one', 0.32727670798634945),
#    (u'troubadour', 0.2050451899994491),
#    (u'find', 0.19220264361026823),
#    (u'remember', 0.18664462240166277),
#    (u'love', -0.17391663128531967),
#    (u'man', -0.16964265153167252),
#    (u'loves', 0.16601569866020879),
#    (u'great', 0.14057379560171385),
#    (u'long', -0.12949009257221913),
#    (u'blow', -0.127286352562896)]),
#  (28,
#   [(u'woman', -0.19133541502218979),
#    (u'river', -0.17859299703102158),
#    (u'got', -0.16937122535533258),
#    (u'die', -0.16022497956083384),
#    (u'enough', -0.15032156628730634),
#    (u'going', -0.14495005141387107),
#    (u'hill', -0.14287427038932882),
#    (u'yes', -0.14193782906621291),
#    (u'know', 0.13101095734824711),
#    (u'time', 0.1299531187500593)]),
#  (29,
#   [(u'nearest', -0.25357848961675522),
#    (u'heaven', -0.24583153770319915),
#    (u'thing', -0.19420408448270687),
#    (u'troubadour', -0.18113703406688031),
#    (u'picking', -0.17665326738884837),
#    (u'love', -0.17660888025428695),
#    (u'come', -0.15875924632161756),
#    (u'time', 0.14687062885729213),
#    (u'watched', -0.13974290438705614),
#    (u'got', 0.13589694756637841)]),
#  (30,
#   [(u'enough', -0.25320937151797618),
#    (u'jesus', -0.1833640074467405),
#    (u'well', -0.18225300093570859),
#    (u'die', 0.16758911190439263),
#    (u'going', 0.15046466786480478),
#    (u'god', -0.13305893226463286),
#    (u'never', -0.1322114312001971),
#    (u'great', -0.12760730825056116),
#    (u'thing', -0.11884649628798165),
#    (u'river', 0.11511493862517133)]),
#  (31,
#   [(u'troubadour', 0.33338661516860585),
#    (u'one', -0.2606176389314046),
#    (u'make', -0.22818470309387234),
#    (u'thing', 0.18576486117794333),
#    (u'lord', 0.15575370875691519),
#    (u'next', -0.15405310692388602),
#    (u'goodbye', 0.14616511572316301),
#    (u'nearest', 0.14493050234271054),
#    (u'love', -0.1294284617264847),
#    (u'like', 0.12815631408575476)]),
#  (32,
#   [(u'another', -0.26837437686957721),
#    (u'gonna', -0.23953156784148613),
#    (u'troubadour', 0.23820650806778224),
#    (u'make', 0.19040087807879524),
#    (u'lot', 0.15200759089674301),
#    (u'gone', -0.14715536536112792),
#    (u'thanks', 0.14700733121230233),
#    (u'next', 0.13766629891249527),
#    (u'hill', 0.13124874400876321),
#    (u'heaven', -0.12763287517195426)]),
#  (33,
#   [(u'leave', -0.2504828658365657),
#    (u'hill', -0.20604984182308606),
#    (u'river', 0.17933745981922525),
#    (u'yes', -0.16761231519137978),
#    (u'die', -0.15201552723648518),
#    (u'big', 0.14862114924322212),
#    (u'young', -0.14427879427132681),
#    (u'rather', -0.1412535648122285),
#    (u'woman', 0.13643918490448184),
#    (u'right', 0.12283224460587516)]),
#  (34,
#   [(u'die', 0.18660684060438332),
#    (u'rather', 0.17988284826250656),
#    (u'young', 0.17379782098084326),
#    (u'clementine', -0.1710232692166527),
#    (u'cody', -0.1710232692166527),
#    (u'leave', 0.16351596293106668),
#    (u'well', 0.15462719544716227),
#    (u'got', -0.14911830683759006),
#    (u'never', 0.14804120839345328),
#    (u'home', 0.144936263073522)]),
#  (35,
#   [(u'cody', -0.1940715418255273),
#    (u'clementine', -0.1940715418255273),
#    (u'another', -0.19406825606033296),
#    (u'home', -0.15159788350653389),
#    (u'frankie', 0.14664287308786389),
#    (u'yes', -0.13281796222670092),
#    (u'hill', -0.1317657489662282),
#    (u'could', 0.13143368731800106),
#    (u'someone', -0.12780365692004081),
#    (u'gonna', -0.12621652435611469)]),
#  (36,
#   [(u'leave', -0.23904844687248691),
#    (u'cooking', 0.22297908298371627),
#    (u'young', -0.21924400011449668),
#    (u'rather', -0.21217301640485128),
#    (u'die', -0.19213668919474591),
#    (u'lot', -0.18799718180753128),
#    (u'thanks', -0.17379645083631026),
#    (u'home', 0.14599143207274776),
#    (u'looking', 0.14410722192348452),
#    (u'lord', -0.137717072433058)]),
#  (37,
#   [(u'great', -0.27585649985293437),
#    (u'shepherd', 0.19741518786439866),
#    (u'goodbye', -0.16924729672122013),
#    (u'loves', 0.16692892968285092),
#    (u'speckled', -0.16175595344661695),
#    (u'bird', -0.16175595344661695),
#    (u'name', -0.14640249978415179),
#    (u'going', -0.13465477332588704),
#    (u'god', -0.13369026810385159),
#    (u'heart', 0.12736409395886336)]),
#  (38,
#   [(u'could', -0.26648185685128872),
#    (u'enough', -0.17474042410641114),
#    (u'got', 0.17266121416229244),
#    (u'remember', 0.16995249605564428),
#    (u'lord', 0.16150627840321413),
#    (u'many', -0.14576720346016836),
#    (u'loves', 0.1447359683681114),
#    (u'one', 0.1443553449849555),
#    (u'john', 0.14266769095032877),
#    (u'make', -0.12636930895313281)]),
#  (39,
#   [(u'cody', -0.20393389007626586),
#    (u'clementine', -0.20393389007626586),
#    (u'thanks', 0.19434413798047179),
#    (u'lot', 0.18878389563619458),
#    (u'shepherd', 0.1706086020729484),
#    (u'love', -0.15628977470887462),
#    (u'ways', -0.15243906811124308),
#    (u'heart', 0.13721823959650933),
#    (u'loves', 0.13702339804091099),
#    (u'woman', -0.1365689749234979)]),
#  (40,
#   [(u'shepherd', 0.26699689845840119),
#    (u'heart', 0.19177788965305162),
#    (u'next', -0.17361948225992843),
#    (u'another', -0.16931037462883225),
#    (u'gonna', -0.16447118572181132),
#    (u'troubadour', -0.15242912847146259),
#    (u'well', -0.14387932491957758),
#    (u'break', -0.13989575246963784),
#    (u'dying', -0.13968711727387412),
#    (u'joe', -0.13702939521486099)]),
#  (41,
#   [(u'many', 0.19307625247911447),
#    (u'darling', 0.16315256784727863),
#    (u'see', 0.16245791547667229),
#    (u'make', -0.16186241487875067),
#    (u'want', -0.15325076125483258),
#    (u'next', 0.1492298688467063),
#    (u'shepherd', 0.13839007533602116),
#    (u'ways', 0.1381108556095578),
#    (u'line', 0.12391120276916891),
#    (u'would', -0.11419997147514664)]),
#  (42,
#   [(u'cooking', 0.29365124965258749),
#    (u'could', -0.20997425550365167),
#    (u'looking', 0.19348785690016496),
#    (u'next', 0.14627445701975619),
#    (u'something', 0.14573391309843553),
#    (u'enough', 0.13346036345840798),
#    (u'mother', 0.12982092479540888),
#    (u'way', 0.12309604853326647),
#    (u'roses', 0.11962280161807624),
#    (u'daddy', 0.11962280161807624)]),
#  (43,
#   [(u'cooking', -0.26587412647755571),
#    (u'saw', -0.19116414504812498),
#    (u'dying', 0.18616785901742483),
#    (u'looking', -0.16960150980951746),
#    (u'joe', 0.16823770691343423),
#    (u'many', -0.16007346237857603),
#    (u'days', 0.14300432641669494),
#    (u'apache', -0.13418422389842796),
#    (u'squaw', -0.13418422389842796),
#    (u'old', -0.13035419611169291)]),
#  (44,
#   [(u'shepherd', -0.20544422451858041),
#    (u'prairie', 0.16922051489792328),
#    (u'joe', -0.15838684854427768),
#    (u'dying', -0.14347835078156379),
#    (u'crying', -0.14190774887557819),
#    (u'one', 0.1416033854894046),
#    (u'days', -0.1347650024608455),
#    (u'lay', -0.12606525438337243),
#    (u'hank', -0.12231811477184311),
#    (u'ride', 0.12001790433505578)]),
#  (45,
#   [(u'next', -0.22088810141914522),
#    (u'remember', 0.22009216329379672),
#    (u'old', 0.18540515697907772),
#    (u'line', -0.16993771685777337),
#    (u'loves', 0.15169243424075604),
#    (u'come', -0.13374107881891117),
#    (u'home', -0.12367002768684238),
#    (u'could', -0.12028523355830768),
#    (u'long', -0.1152348801080673),
#    (u'mother', 0.11377218010229544)]),
#  (46,
#   [(u'shepherd', 0.22954192727129111),
#    (u'thought', 0.16000425861182926),
#    (u'know', 0.15902051510976148),
#    (u'prison', 0.15598063586549515),
#    (u'make', -0.15462253957275132),
#    (u'train', 0.12502451697343817),
#    (u'guess', -0.12350169634589418),
#    (u'mother', -0.1205910651858193),
#    (u'bet', 0.10932416606904798),
#    (u'frankie', -0.10853109164519148)]),
#  (47,
#   [(u'could', -0.2132390217430831),
#    (u'instead', -0.19506595254523376),
#    (u'ashamed', -0.19328510057422588),
#    (u'share', -0.15769438701636859),
#    (u'many', 0.15274352614836109),
#    (u'memories', -0.14634100500585914),
#    (u'grace', -0.14629946440892533),
#    (u'keep', 0.11861916274222149),
#    (u'god', -0.11765843392099619),
#    (u'give', -0.11100757133671213)]),
#  (48,
#   [(u'hear', -0.20575386206196711),
#    (u'still', -0.17141426823041928),
#    (u'prison', -0.15727371472897486),
#    (u'could', -0.12044094513846675),
#    (u'train', -0.11255694911921894),
#    (u'waiting', -0.10923452801290991),
#    (u'instead', -0.10533476266208854),
#    (u'folsom', -0.1048491431526499),
#    (u'hang', -0.10433444131658992),
#    (u'doggone', -0.10381973948053)]),
#  (49,
#   [(u'memories', 0.24467000139041623),
#    (u'thought', -0.16718168020283297),
#    (u'john', -0.16656693676035922),
#    (u'keeps', 0.13953791270510277),
#    (u'blues', 0.13821980974500092),
#    (u'want', 0.13341039583826036),
#    (u'prison', 0.12920544627331595),
#    (u'left', 0.12626651275590361),
#    (u'never', 0.12091649109214304),
#    (u'place', 0.12033951775010053)])]

# %%
jsonified = json.dumps(topics_matrix)
with open('./corpus/lyrics_lsa.json', 'w') as handle:
    handle.write(jsonified)

# %% [markdown]
# ### Latent dirichlet allocation
# Allows sets of observations to be explained by unobserved groups that explain why some parts of the data are similar. For example, if observations are words collected into documents, it posits that each document is a mixture of a small number of topics and that each word's creation is attributable to one of the document's topics.
# https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation

# %%
# %time lda = models.LdaModel(corpus_doc2bow, num_topics=5, id2word=dictionary, update_every=5, chunksize=10000, passes=100)
# Out:
# CPU times: user 20.7 s, sys: 144 ms, total: 20.8 s
# Wall time: 22.2 s

# %%
print(lda[corpus_doc2bow[1]])
# Out:
# [(4, 0.99051658090152517)]

# %%
topics = lda.print_topics(50, num_words=10)

# %%
topics
# Out:
# [(0,
#   u'0.018*played + 0.014*got + 0.014*country + 0.013*boy + 0.013*boogie + 0.013*luther + 0.011*good + 0.010*old + 0.010*man + 0.010*woogie'),
#  (1,
#   u'0.012*guns + 0.012*home + 0.011*town + 0.010*still + 0.010*someone + 0.010*miss + 0.008*long + 0.008*take + 0.008*heart + 0.008*love'),
#  (2,
#   u'0.018*got + 0.017*line + 0.014*drink + 0.014*well + 0.013*know + 0.013*rock + 0.013*island + 0.012*heart + 0.011*love + 0.009*mine'),
#  (3,
#   u'0.021*high + 0.017*run + 0.014*guess + 0.013*feet + 0.013*rising + 0.013*dream + 0.013*softly + 0.013*blue + 0.011*well + 0.011*river'),
#  (4,
#   u'0.025*time + 0.022*get + 0.018*tell + 0.016*cry + 0.011*love + 0.010*got + 0.009*come + 0.009*man + 0.009*heart + 0.009*going')]

# %%
# This is a format you can parse more easily to use elsewhere.
topics_matrix = lda.show_topics(formatted=False, num_words=10)
topics_matrix
# Out:
# [(0,
#   [(u'played', 0.017603008167115092),
#    (u'got', 0.014344431044358544),
#    (u'country', 0.014341141682969214),
#    (u'boy', 0.013257531127486623),
#    (u'boogie', 0.013254691503679052),
#    (u'luther', 0.013254691499524849),
#    (u'good', 0.011083007012542431),
#    (u'old', 0.0099983980882499251),
#    (u'man', 0.009997680820432512),
#    (u'woogie', 0.0099953409263772268)]),
#  (1,
#   [(u'guns', 0.012019847623269334),
#    (u'home', 0.011852985412296268),
#    (u'town', 0.011254011796242348),
#    (u'still', 0.0098001096441339419),
#    (u'someone', 0.0097951681971523152),
#    (u'miss', 0.0097939837549156378),
#    (u'long', 0.008310830180967085),
#    (u'take', 0.0083049893562906658),
#    (u'heart', 0.0080824445470123081),
#    (u'love', 0.0080141150900709807)]),
#  (2,
#   [(u'got', 0.018000692198410079),
#    (u'line', 0.017107655423963912),
#    (u'drink', 0.014432685403469318),
#    (u'well', 0.013543657615898139),
#    (u'know', 0.012653344951246256),
#    (u'rock', 0.012652365330307778),
#    (u'island', 0.01265087312355806),
#    (u'heart', 0.011762809694817163),
#    (u'love', 0.010871786080250913),
#    (u'mine', 0.0090909706319262026)]),
#  (3,
#   [(u'high', 0.020837688977348941),
#    (u'run', 0.016908409089428294),
#    (u'guess', 0.014214430777936958),
#    (u'feet', 0.012977480206864084),
#    (u'rising', 0.012975335606301477),
#    (u'dream', 0.012974999655179209),
#    (u'softly', 0.012948100415334814),
#    (u'blue', 0.012694982647740719),
#    (u'well', 0.01128147581625309),
#    (u'river', 0.011008571709076397)]),
#  (4,
#   [(u'time', 0.024980137436756911),
#    (u'get', 0.021598898326876902),
#    (u'tell', 0.01816035079236536),
#    (u'cry', 0.016240319201401177),
#    (u'love', 0.011043807426578147),
#    (u'got', 0.009878084138606448),
#    (u'come', 0.0093910307206889598),
#    (u'man', 0.0093903187315604215),
#    (u'heart', 0.0090397300233363773),
#    (u'going', 0.0089019643137498317)])]

# %%
jsonified = json.dumps(topics_matrix)
with open('./corpus/lyrics_lda.json', 'w') as handle:
    handle.write(jsonified)

# %%
from nltk.data import BufferedGzipFile
